# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
data_set = 'mnist'
epoch = 300
batch_size = 1024
hidden_size = [16, 128, 512, 1024]
layer = [2, 4, 6, 8, 10]
nameAll = []
accAll = []
valaccAll = []
vallossAll = []
lossAll = []
paramsAll = []

for i in xrange(3):    
    for l in layer:
        for size in hidden_size:
            with open('./%s/%d_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size), 'r') as history:
                #print('./%s/%d_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size))
                h = json.load(history)
                acc = np.array(h.get('acc'))
                valacc = np.array(h.get('val_acc'))
                loss = np.array(h.get('loss'))
                valloss = np.array(h.get('val_loss'))
                valaccAll.append(valacc)
                vallossAll.append(valloss)
                lossAll.append(loss)
                nameAll.append('%s_%d_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size))
                accAll.append(acc)
            for line in open('./%s/batch_size_%d_layer_%d_hidden_size_%d_summary' % (data_set, batch_size, l, size), 'r'):
                if 'Total params' in line:
                    params = int(line.replace(',', '').split(' ')[2])
                    paramsAll.append(params)
    break

for i in xrange(len(paramsAll)):
    print 'Index: %d, %s, params %d' % (i, np.array(nameAll[i]) , paramsAll[i])
    
pairs = [3, 10]

plt.figure(1)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

pairs = [7, 10]

plt.figure(2)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

pairs = [0, 16]

plt.figure(2)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

# %%
for l in xrange(len(layer)):
    plt.figure(l)
    for size in xrange(len(hidden_size)):
        plt.plot(accAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('acc')
    plt.xlim(0, epoch)
    plt.legend()
    plt.show()

for size in xrange(len(hidden_size)):
    plt.figure(size)
    for l in xrange(len(layer)):
               plt.plot(accAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('acc')
    plt.xlim(0, epoch)
    plt.ylim(0., 1.)
    plt.legend()
    plt.show()

for l in xrange(len(layer)):
    plt.figure(l)
    for size in xrange(len(hidden_size)):
                plt.plot(lossAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xlim(0, epoch)
    plt.ylim(0., 1.)
    plt.legend()
    plt.show()
    
for size in xrange(len(hidden_size)):
    plt.figure(size)
    for l in xrange(len(layer)):
         plt.plot(lossAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xlim(0, epoch)
    plt.ylim()
    plt.legend()
    plt.show()

# %%
nameAll = []
accAll = []
valaccAll = []
vallossAll = []
lossAll = []
paramsAll = []
epoch = 1000
for i in xrange(3):    
    for l in layer:
        for size in hidden_size:
            with open('./%s/%d_random_label_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size), 'r') as history:
                #print('./%s/%d_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size))
                h = json.load(history)
                acc = np.array(h.get('acc'))
                valacc = np.array(h.get('val_acc'))
                loss = np.array(h.get('loss'))
                valloss = np.array(h.get('val_loss'))
                valaccAll.append(valacc)
                vallossAll.append(valloss)
                lossAll.append(loss)
                nameAll.append('%s_%d_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, batch_size, l, size))
                accAll.append(acc)
            for line in open('./%s/batch_size_%d_layer_%d_hidden_size_%d_summary' % (data_set, batch_size, l, size), 'r'):
                if 'Total params' in line:
                    params = int(line.replace(',', '').split(' ')[2])
                    paramsAll.append(params)
    break

pairs = [3, 10]

plt.figure(1)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

pairs = [7, 10]

plt.figure(2)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

pairs = [0, 16]

plt.figure(2)
plt.plot(accAll[pairs[0]], label=nameAll[pairs[0]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[0]])
plt.plot(accAll[pairs[1]], label=nameAll[pairs[1]].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[pairs[1]])
plt.xlabel('epoch')
plt.ylabel('acc')
plt.xlim(0, 200)
plt.ylim(0., 1.)
plt.legend()
plt.show()

# %%
for l in xrange(len(layer)):
    plt.figure(l)
    for size in xrange(len(hidden_size)):
        plt.plot(accAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('acc')
    plt.xlim(0, epoch)
    plt.ylim(0., 1.)
    plt.legend()
    plt.show()

for size in xrange(len(hidden_size)):
    plt.figure(size)
    for l in xrange(len(layer)):
               plt.plot(accAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('acc')
    plt.xlim(0, epoch)
    plt.ylim(0., 1.)
    plt.legend()
    plt.show()

for l in xrange(len(layer)):
    plt.figure(l)
    for size in xrange(len(hidden_size)):
                plt.plot(lossAll[(len(hidden_size))*l + size],
                label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xlim(0, epoch)
    plt.ylim(0., 1.)
    plt.legend()
    plt.show()
    
for size in xrange(len(hidden_size)):
    plt.figure(size)
    for l in xrange(len(layer)):
         plt.plot(lossAll[(len(hidden_size))*l + size],
                 label=nameAll[(len(hidden_size))*l + size].split(str(batch_size)+'_')[1] +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xlim(0, epoch)
    plt.ylim()
    plt.legend()
    plt.show()

# %%
gaussian_proportion = [.0, .2, .4, .6, .8, 1.]
hidden_size = [16, 512, 1024]
layer = [2, 4, 8]
nameAll = []
accAll = []
valaccAll = []
vallossAll = []
lossAll = []
paramsAll = []
testaccAll = []
testlossAll = []
epoch = 1000

for i in xrange(3): 
    for proportion in gaussian_proportion:
        for l in layer:
            for size in hidden_size:
                with open('./%s/%d_gaussian_%f_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, proportion, batch_size, l, size), 'r') as history:
                    #print('./%s/%d_gaussian_%f_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, proportion, batch_size, l, size))
                    h = json.load(history)
                    acc = np.array(h.get('acc'))
                    valacc = np.array(h.get('val_acc'))
                    loss = np.array(h.get('loss'))
                    valloss = np.array(h.get('val_loss'))
                    valaccAll.append(valacc)
                    vallossAll.append(valloss)
                    lossAll.append(loss)
                    nameAll.append('%s_%d_gaussian_%.1f_batch_size_%d_layer_%d_hidden_size_%d' % (data_set, i+1, proportion, batch_size, l, size))
                    accAll.append(acc)
                for line in open('./%s/gaussian_%f_batch_size_%d_layer_%d_hidden_size_%d_summary' % (data_set, proportion, batch_size, l, size), 'r'):
                    if 'Total params' in line:
                        params = int(line.replace(',', '').split(' ')[2])
                        paramsAll.append(params)
                    if 'score' in line:
                        testloss = float(line.split(' ')[1])
                        testacc = float(line.split(' ')[2])
                        testaccAll.append(testacc)
                        testlossAll.append(testloss)
    break

for proportion in xrange(len(gaussian_proportion)):    
    print nameAll[len(layer)*len(hidden_size)*proportion].replace('_batch_size_1024', '').replace('mnist_1_', '')

for l in xrange(len(layer)):
    for size in xrange(len(hidden_size)):
        plt.figure(size)
        index = 0
        for proportion in xrange(len(gaussian_proportion)):
            index = len(layer)*len(hidden_size)*proportion + (size + len(hidden_size)*l)
            print nameAll[index].replace('_batch_size_1024', '').replace('mnist_1_', '')
            plt.plot(accAll[index], label=nameAll[index].split('_')[2] +'_'+ nameAll[index].split('_')[3])
        plt.title('layer %d hidden_size %d #params %d' % (layer[l], hidden_size[size], paramsAll[index]))
        plt.xlabel('epoch')
        plt.ylabel('acc')
        plt.xlim(0, epoch)
        plt.ylim(0., 1)
        plt.legend()
        plt.show()

'''
for proportion in xrange(len(gaussian_proportion)):
    for l in xrange(len(layer)):
        plt.figure(size)
        for size in xrange(len(hidden_size)):
            print nameAll[(len(hidden_size))*l + size].replace('_batch_size_1024', '').replace('mnist_1_', '')
            plt.plot(accAll[(len(hidden_size))*l + size], label=nameAll[(len(hidden_size))*l + size].replace('_batch_size_1024', '').replace('mnist_1_', '') +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
        plt.xlabel('epoch')
        plt.ylabel('acc')
        plt.xlim(0, 200)
        plt.ylim(0., 1)
        plt.legend()
        plt.show()
    
for proportion in xrange(len(gaussian_proportion)):
    for size in xrange(len(hidden_size)):
        plt.figure(size)
        for l in xrange(len(layer)):
            print nameAll[(len(hidden_size))*l*proportion + size].replace('_batch_size_1024', '').replace('mnist_1_', '')
            plt.plot(lossAll[(len(hidden_size))*proportion + size], label=nameAll[(len(hidden_size))*l + size].replace('_batch_size_1024', '').replace('mnist_1_', '') +' #params_%d' % paramsAll[(len(hidden_size))*l + size])
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.xlim(0, 200)
        plt.ylim(0., 1)
        plt.legend()
        plt.show()
'''
